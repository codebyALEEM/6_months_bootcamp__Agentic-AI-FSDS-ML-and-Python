# %%
1
# Out:
# 1

# %%
1 + 2 #Addition
# Out:
# 3

# %%
1 - 2 #Subtraction
# Out:
# -1

# %%
20 * 5 #Multiplacation
# Out:
# 100

# %%
50 / 5 #Division
# Out:
# 10.0

# %%
50 // 5 #Floor Division
# Out:
# 10

# %%
50 % 5 #Modulus
# Out:
# 0

# %%
50 % 4 #Modulus
# Out:
# 2

# %%
3 * 3 #Multiplication
# Out:
# 9

# %%
3 ** 3 #Exponential
# Out:
# 27

# %%
_
# Out:
# 27

# %%
25
# Out:
# 25

# %%
_
# Out:
# 25

# %%
_ + 5
# Out:
# 30

# %%
_ - 2
# Out:
# 28

# %%
(3 + 4) - 3 * 6
# Out:
# -11

# %%
4 + (15 - 6) * 9
# Out:
# 85

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %%
plt.plot([3,6,9,12],[2,4,6,8])
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)

plt.title('My First Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [15,18,25,26,29]
y = [2,8,11,13,16]

plt.plot(x,y)

plt.title('My first plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()
