# %% [markdown]
# INTRODUCTION TO OPENCV AND IMAGE PROCESSING

# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\VICTUS\Desktop\LinkedIn\Upgrade cv2\Opencv\rbt2.jpeg')

# %%
img
# Out:
# array([[[206, 194, 130],
#         [207, 195, 131],
#         [207, 195, 131],
#         ...,
#         [225, 217, 170],
#         [225, 217, 170],
#         [225, 217, 170]],
#
#        [[206, 194, 130],
#         [207, 195, 131],
#         [207, 195, 131],
#         ...,
#         [225, 217, 170],
#         [225, 217, 170],
#         [225, 217, 170]],
#
#        [[206, 194, 130],
#         [207, 195, 131],
#         [207, 195, 131],
#         ...,
#         [225, 217, 170],
#         [225, 217, 170],
#         [225, 217, 170]],
#
#        ...,
#
#        [[189, 174, 111],
#         [189, 174, 111],
#         [189, 174, 111],
#         ...,
#         [ 89,  94,  63],
#         [ 89,  94,  63],
#         [ 89,  94,  63]],
#
#        [[187, 173, 114],
#         [187, 173, 114],
#         [187, 173, 114],
#         ...,
#         [ 88,  94,  63],
#         [ 86,  92,  61],
#         [ 89,  95,  64]],
#
#        [[187, 173, 115],
#         [187, 173, 115],
#         [187, 173, 115],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1314, 736, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[130, 194, 206],
#         [131, 195, 207],
#         [131, 195, 207],
#         ...,
#         [170, 217, 225],
#         [170, 217, 225],
#         [170, 217, 225]],
#
#        [[130, 194, 206],
#         [131, 195, 207],
#         [131, 195, 207],
#         ...,
#         [170, 217, 225],
#         [170, 217, 225],
#         [170, 217, 225]],
#
#        [[130, 194, 206],
#         [131, 195, 207],
#         [131, 195, 207],
#         ...,
#         [170, 217, 225],
#         [170, 217, 225],
#         [170, 217, 225]],
#
#        ...,
#
#        [[111, 174, 189],
#         [111, 174, 189],
#         [111, 174, 189],
#         ...,
#         [ 63,  94,  89],
#         [ 63,  94,  89],
#         [ 63,  94,  89]],
#
#        [[114, 173, 187],
#         [114, 173, 187],
#         [114, 173, 187],
#         ...,
#         [ 63,  94,  88],
#         [ 61,  92,  86],
#         [ 64,  95,  89]],
#
#        [[115, 173, 187],
#         [115, 173, 187],
#         [115, 173, 187],
# ...

# %%
fix_img.shape
# Out:
# (1314, 736, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\VICTUS\Desktop\LinkedIn\Upgrade cv2\Opencv\rbt2.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1314, 736)

# %%
img_gray
# Out:
# array([[176, 177, 177, ..., 204, 204, 204],
#        [176, 177, 177, ..., 204, 204, 204],
#        [176, 177, 177, ..., 204, 204, 204],
#        ...,
#        [157, 157, 157, ...,  84,  84,  84],
#        [157, 157, 157, ...,  84,  82,  85],
#        [157, 157, 157, ...,  84,  82,  85]],
#       shape=(1314, 736), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(img_gray,cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1314, 736, 3)

# %%
fix_img1 = cv2.resize(fix_img,(199,300))

# %%
fix_img1.shape
# Out:
# (300, 199, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img2
# Out:
# array([[[131, 195, 207],
#         [132, 196, 208],
#         [134, 196, 209],
#         ...,
#         [170, 217, 225],
#         [170, 217, 225],
#         [170, 217, 225]],
#
#        [[131, 195, 207],
#         [132, 196, 208],
#         [134, 196, 209],
#         ...,
#         [170, 217, 225],
#         [170, 217, 225],
#         [170, 217, 225]],
#
#        [[131, 195, 207],
#         [132, 196, 208],
#         [134, 196, 209],
#         ...,
#         [172, 216, 225],
#         [172, 216, 225],
#         [172, 216, 225]],
#
#        ...,
#
#        [[105, 155, 172],
#         [106, 158, 174],
#         [109, 161, 177],
#         ...,
#         [ 63,  93,  91],
#         [ 63,  93,  91],
#         [ 63,  93,  91]],
#
#        [[112, 174, 189],
#         [111, 173, 188],
#         [110, 172, 187],
#         ...,
#         [ 63,  94,  90],
#         [ 63,  94,  90],
#         [ 63,  94,  90]],
#
#        [[115, 173, 187],
#         [115, 173, 187],
#         [115, 172, 186],
# ...

# %%
plt.imshow(fix_img2)

# %%
img3 = cv2.flip(fix_img2,0)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img2,1)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img2,2)
plt.imshow(img3)
